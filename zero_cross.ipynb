# %%
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np

# %%
signal1, fm = sf.read("prueba.wav")
t = np.arange(0, len(signal1)) / fm

# %%
"""
Gráficas de los diferentes medias estadísticas de la señal de entrada
"""
fig, axs = plt.subplots(2,1)
fig.set_size_inches(10,10)
axs[0].set_title("Señal original")
axs[0].set_ylabel("Amplitud")
axs[0].set_xlabel("time")
axs[0].grid(True)
axs[0].plot(t, signal1)

fig.set_size_inches(10,10)
axs[1].set_title("Señal modificada")
axs[1].set_ylabel("Amplitud")
axs[1].set_xlabel("time")
axs[1].grid(True)
axs[1].plot(t2, signal2)

fig.tight_layout()
plt.show()

# %%
fig.savefig('p2_results.png', dpi=400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 fig.savefig('p1_results.png', dpi=400)
#
# NameError: name 'fig' is not defined
